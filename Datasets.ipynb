# %% [markdown]
# <img title="GitHub Octocat" src='./img/Octocat.jpg?raw=true' style='height: 60px; padding-right: 15px' alt="Octocat" align="left"> This notebook is part of a GitHub repository: https://github.com/pessini/avian-flu-wild-birds-ireland
# <br>MIT Licensed
# <br>Author: Leandro Pessini

# %% [markdown]
# # <p style="font-size:100%; text-align:left; color:#444444;">Gathering Data</p>

# %% [markdown]
# ## Ordnance Survey *Ireland* (OSi) - Ireland’s National Mapping Agency
#
# <img title="Ordnance Survey Ireland (OSi)" src="img/Logo-Colour-298x100.jpeg" alt="Ireland’s National Mapping Agency" align="right" style='height:120px; padding: 15px'>The spacial data is provided by [**Ordnance Survey *Ireland* (OSi)**](https://www.osi.ie/) under [Creative Commons licence](https://creativecommons.org/licenses/by/4.0/legalcode).
#
# Ordnance Survey Ireland has evolved from the Ordnance Survey Office which was established in 1824, later becoming a state body under the Ordnance Survey Ireland Act 2001. Under this Act, Ordnance Survey Ireland continued its mainstream public service function of creating and maintaining the definitive mapping records of the State and also assumed the commercial function assigned to it under the Act of developing its commercial business and sales revenues.
#
# **Administrative Areas** dataset generated from the [**2019 OSi National Statutory Boundary dataset**](https://data-osi.opendata.arcgis.com/datasets/OSi::administrative-areas-osi-national-statutory-boundaries-/about).
#
# Dataset License: https://creativecommons.org/licenses/by/4.0/

# %%
import geopandas as gpd
import json
from pathlib import Path

# %%
url_geoJSON = 'https://opendata.arcgis.com/datasets/0d5984f732c54246bd087768223c92eb_0.geojson'
admin_areas_json = 'data/Administrative_Areas_Ireland.json'

# %%
# GeoJSON API
admin_areas = gpd.read_file(url_geoJSON, driver='GeoJSON')

# Saving the data downloaded to a local json file
admin_areas.to_file(admin_areas_json, driver='GeoJSON')

# %%
admin_areas.head()
# Out:
#                   ENGLISH GAEILGE             CONTAE   COUNTY  PROVINCE  \
# 0     DUBLIN CITY COUNCIL    None  Baile Átha Cliath   DUBLIN  Leinster
# 1       CORK CITY COUNCIL    None           Corcaigh     CORK   Munster
# 2     GALWAY CITY COUNCIL    None           Gaillimh   GALWAY  Connacht
# 3   OFFALY COUNTY COUNCIL    None        Uíbh Fhailí   OFFALY  Leinster
# 4  WICKLOW COUNTY COUNCIL    None      Cill Mhantáin  WICKLOW  Leinster
#
#                                    GUID  CENTROID_X  CENTROID_Y          AREA  \
# 0  2ae19629-1433-13a3-e055-000000000001   716469.75   735272.06  1.283502e+08
# 1  2ae19629-1434-13a3-e055-000000000001   565833.13   571933.83  1.865976e+08
# 2  2ae19629-1435-13a3-e055-000000000001   530067.66   726500.52  5.069505e+07
# 3  2ae19629-1496-13a3-e055-000000000001   631261.72   709672.35  2.000025e+09
# 4  2ae19629-149e-13a3-e055-000000000001   707784.79   690738.10  2.025161e+09
#
#     CC_ID  OBJECTID   Shape__Area  Shape__Length  \
# 0  265011         1  1.283502e+08  101493.212412
# 1   45511         2  1.865976e+08   80293.730785
# 2   65011         3  5.069505e+07   64020.725628
# 3  185001         4  2.000025e+09  389927.708615
# 4  255001         5  2.025161e+09  320629.958733
#
#                                             geometry
# 0  POLYGON ((-6.38258 53.33367, -6.38261 53.33370...
# 1  POLYGON ((-8.38436 51.90533, -8.38425 51.90529...
# 2  MULTIPOLYGON (((-9.13605 53.26682, -9.13606 53...
# 3  POLYGON ((-7.97902 53.33689, -7.97878 53.33684...
# 4  MULTIPOLYGON (((-6.14602 52.78372, -6.14607 52...

# %% [markdown]
# ## BirdWatch Ireland - Species & Habitat Conservation

# %% [markdown]
# <img title="BirdWatch Ireland" src="img/BWI_logo_03_80px@2x.webp" alt="BirdWatch Ireland" style='height:150px; padding: 15px' align = "right">**BirdWatch Ireland** is the largest independent conservation organisation in Ireland and their objective is the protection of wild birds and their habitats. They have been doing an incredible work protecting birds and biodiversity in Ireland. Check out their amazing work [here](https://birdwatchireland.ie/our-work/).
#
# The data is collected using **Web Scraping** technique from BirdWatch Ireland's website. There is a [list of Ireland's birds](https://birdwatchireland.ie/irelands-birds-birdwatch-ireland/list-of-irelands-birds/) with detailed information on every species.
#
# To create our dataset and merge with the data provided by the Department of Agriculture, Food and the Marine, the focus will be on the bird's image and common name.

# %%
#!pip3 install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import urllib
from urllib import parse
import cv2
from skimage import io
from PIL import Image

# %% [markdown]
# `scikit-image imread`: OpenCV represents images in BGR order, whereas scikit-image represents images in RGB order. To utilize OpenCV functions after downloading the image, there is a extra step which is to convert the image from RGB to BGR.

# %%
# div class birds-with-filters (Parent)
# page/2/
no_pages = 24

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://birdwatchireland.ie/irelands-birds-birdwatch-ireland/list-of-irelands-birds/'+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('article', attrs={'class':'bird'}):
        
        # image
        image_div = d.find('div', attrs={'class':'bird-img'})
        img_html = image_div.find('img')

        # text
        bird_name = d.find('h3', attrs={'class':'title'})
#         irish_name = d.find('span', attrs={'class':'a-icon-alt'})
#         scientific_name = d.find('a', attrs={'class':'a-size-small a-link-normal'})
#         bird_family = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if img_html is not None:
            str_image = img_html['data-src']
            print(str_image)
            image = io.imread(urllib.parse.quote(str_image, safe=':/'))
            all1.append(image)
        else:
            all1.append("img")

        if bird_name is not None:
            print(bird_name.text)
            all1.append(bird_name.text)
        else:    
            all1.append('0')

#         if rating is not None:
#             #print(rating.text)
#             all1.append(rating.text)
#         else:
#             all1.append('-1')

#         if users_rated is not None:
#             #print(price.text)
#             all1.append(users_rated.text)
#         else:
#             all1.append('0')     

#         if price is not None:
#             #print(price.text)
#             all1.append(price.text)
#         else:
#             all1.append('0')
        alls.append(all1)    
    return alls

# %%
results = []
# for i in range(1, no_pages+1):
for i in range(1, no_pages+1):
    url_to_append = "page/{}/".format(i)
    print(url_to_append)
    results.append(get_data(url_to_append))
flatten = lambda l: [item for sublist in l for item in sublist]
df_birds = pd.DataFrame(flatten(results),columns=['Image','Bird_Name'])
df_birds.to_csv('BirdWatch.csv', index=False)
# Out:
# page/1/
# https://birdwatchireland.ie/app/uploads/2019/03/Arctic-Tern-2015-Rockabill-B-Burke-1-e1556097265390.jpg
# Arctic Tern
# https://birdwatchireland.ie/app/uploads/2019/04/Balearic-Shearwater_Celtic-Sea_off-Cork_RV-Celtic-Explorer_23rd-October-2014_Niall-T.-Keogh-8.jpg
# Balearic Shearwater
# https://birdwatchireland.ie/app/uploads/2019/04/Bar-tailed-Godwit-05-Colm-Fitzpatrick.jpg
# Bar-tailed Godwit
# https://birdwatchireland.ie/app/uploads/2019/04/Barn-Owl-30-Andrew-Kelly.jpg
# Barn Owl
# https://birdwatchireland.ie/app/uploads/2019/01/Barnacle-Goose-12-Ronnie-Martin.jpg
# Barnacle Goose
# https://birdwatchireland.ie/app/uploads/2019/04/Bean-Goose-Sergey-Yeliseev-e1555496205709.jpg
# Bean Goose
# https://birdwatchireland.ie/app/uploads/2019/04/Bewicks-Swan-Michael-Day.jpg
# Bewick’s Swan
# https://birdwatchireland.ie/app/uploads/2019/04/Black-Brant-Alaska-Region-U.S.-Fish-Wildlife-Service.jpg
# Black Brant
# https://birdwatchireland.ie/app/uploads/2019/05/27860881534_9c53657784_o.jpg
# Black Guillemot
# page/2/
# https://birdwatchireland.ie/app/uploads/2019/04/Black-Redstart-24-John-Fox.jpg
# Black Redstart
# https://birdwatchireland.ie/app/uploads/2019/04/Black-headed-Gull-A04-Michael-Finn.jpg
# Black-headed Gull
# https://birdwatchireland.ie/app/uploads/2019/04/Black-necked-Grebe-Paul-Green-1.jpg
# Black-necked Grebe
# https://birdwatchireland.ie/app/uploads/2019/04/Black-tailed-Godwit-03-Jerry-Cassidy.jpg
# Black-tailed Godwit
# https://birdwatchireland.ie/app/uploads/2019/04/Black-throated-Diver-Vince.jpg
# Black-throated Diver
# https://birdwatchireland.ie/app/uploads/2019/04/Blackbird-03-Jerry-Cassidy.jpg
# Blackbird
# https://birdwatchireland.ie/app/uploads/2019/04/Blackcap-41-Dick-Coombes.jpg
# Blackcap
# https://birdwatchireland.ie/app/uploads/2019/03/Blue-Tit-_0303a-DC-e1555488980259.jpg
# Blue Tit
# https://birdwatchireland.ie/app/uploads/2019/04/Brambling-30-Peter-Walsh-e1600681279135.jpg
# Brambling
# page/3/
# https://birdwatchireland.ie/app/uploads/2019/04/Dark-bellied-Brent-Goose-Donald-Hobern.jpg
# Shelduck
# https://birdwatchireland.ie/app/uploads/2019/02/Short-eared-Owl-66-Neil-O-Reilly.jpg
# Short-eared Owl
# https://birdwatchireland.ie/app/uploads/2019/02/Shoveler-10-Ken-Kinsella.jpg
# Shoveler
# https://birdwatchireland.ie/app/uploads/2019/02/Siskin-17-male-Shay-Connolly.jpg
# Siskin
# https://birdwatchireland.ie/app/uploads/2019/02/Skylark-19-Dick-Coombes-e1554819725352.jpg
# Skylark
# https://birdwatchireland.ie/app/uploads/2019/02/Slavonian-Grebe-05-Iceland-Ken-Kinsella.jpg
# Slavonian Grebe
# page/20/
# https://birdwatchireland.ie/app/uploads/2019/02/Smew-04-drake-Graham-Catley.jpg
# Smew
# https://birdwatchireland.ie/app/uploads/2019/02/Snipe-copy-e1555504853999.jpg
# Snipe
# https://birdwatchireland.ie/app/uploads/2019/02/Snow-Bunting-55-Shay-Connolly.jpg
# Snow Bunting
# https://birdwatchireland.ie/app/uploads/2019/02/Snow-Goose-06-white-phase-Ronnie-Martin-e1554808994656.jpg
# Snow Goose
# https://birdwatchireland.ie/app/uploads/2019/02/Snowy-Owl-08-with-kill-René-Bruun.jpg
# Snowy Owl
# https://birdwatchireland.ie/app/uploads/2019/02/Song-Thrush-33-Neil-van-Dokkum.jpg
# Song Thrush
# https://birdwatchireland.ie/app/uploads/2019/02/Sooty-Shearwater-11-Jamie-Durrant.jpg
# Sooty Shearwater
# https://birdwatchireland.ie/app/uploads/2019/02/Sparrowhawk-male-taking-flight-Tom-Ormond.jpg
# Sparrowhawk
# https://birdwatchireland.ie/app/uploads/2019/02/Spotted-Flycatcher-09-Clive-Timmons.jpg
# Spotted Flycatcher
# page/21/
# https://birdwatchireland.ie/app/uploads/2019/04/Spotted-Redshank-Gideon-Chilton.jpg
# Spotted Redshank
# https://birdwatchireland.ie/app/uploads/2019/01/Starling-P08-Michael-Finn.jpg
# Starling
# https://birdwatchireland.ie/app/uploads/2019/02/Stock-Dove-04-John-Fox.jpg
# Stock Dove
# https://birdwatchireland.ie/app/uploads/2019/02/Stonechat-A11-male-Shay-Connolly.jpg
# Stonechat
# https://birdwatchireland.ie/app/uploads/2019/02/European-Storm-Petrel-15-Anthony-McGeehan.jpg
# Storm Petrel
# https://birdwatchireland.ie/app/uploads/2019/04/Surf-Scoter-Paul-VanDerWerf.jpg
# Surf Scoter
# https://birdwatchireland.ie/app/uploads/2019/02/Swallow-95-Colum-Clarke.jpg
# Swallow
# https://birdwatchireland.ie/app/uploads/2019/04/Swift-_8806-D-Coombes.jpg
# Swift
# https://birdwatchireland.ie/app/uploads/2019/03/Teal-32-Michael-Finn.jpg
# Teal
# page/22/
# https://birdwatchireland.ie/app/uploads/2019/02/Tree-Sparrow-JF03-John-Fox.jpg
# Tree Sparrow
# https://birdwatchireland.ie/app/uploads/2019/02/Treecreeper-47-John-Fox.jpg
# Treecreeper
# https://birdwatchireland.ie/app/uploads/2019/02/Tufted-Duck-P01-Michael-Finn.jpg
# Tufted Duck
# https://birdwatchireland.ie/app/uploads/2019/01/Turnstone-SHC05-Shay-Connolly.jpg
# Turnstone
# https://birdwatchireland.ie/app/uploads/2019/01/Turtle-Dove-05-Derek-Lawlor.jpg
# Turtle Dove
# https://birdwatchireland.ie/app/uploads/2019/01/Twite-09-Ken-Kinsella.jpg
# Twite
# https://birdwatchireland.ie/app/uploads/2019/04/Velvet-Scoter-Åsa-Berndtsson.jpg
# Velvet Scoter
# https://birdwatchireland.ie/app/uploads/2019/02/Water-Rail-ViCo04-Vicky-Comerford-http_vickysphotography.ie_.jpg
# Water Rail
# https://birdwatchireland.ie/app/uploads/2019/01/Waxwing-83-Dick-Coombes.jpg
# Waxwing
# page/23/
# https://birdwatchireland.ie/app/uploads/2019/01/Wheatear-21-Tom-Shevlin.jpg
# Wheatear
# https://birdwatchireland.ie/app/uploads/2019/01/Whimbrel-19-Scotland.jpg
# Whimbrel
# https://birdwatchireland.ie/app/uploads/2019/01/Whinchat-Stephen-Lawlor.jpg
# Whinchat
# https://birdwatchireland.ie/app/uploads/2019/01/White-tailed-Eagle-01-Mike-Brown.jpg
# White-tailed Eagle
# https://birdwatchireland.ie/app/uploads/2019/01/Whitethroat-22-Shay-Connolly.jpg
# Whitethroat
# https://birdwatchireland.ie/app/uploads/2019/01/Whooper-Swan-12-Ken-Kinsella.jpg
# Whooper Swan
# https://birdwatchireland.ie/app/uploads/2019/01/Wigeon-21-Colm-Fitzpatrick.jpg
# Wigeon
# https://birdwatchireland.ie/app/uploads/2019/01/Willow-Warbler-05-Tom-Shevlin.jpg
# Willow Warbler
# https://birdwatchireland.ie/app/uploads/2019/01/Wood-Sandpiper-05-John-N-Murphy.jpg
# Wood Sandpiper
# page/24/
# https://birdwatchireland.ie/app/uploads/2019/01/Wood-Warbler-03-David-Dillon.jpg
# Wood Warbler
# https://birdwatchireland.ie/app/uploads/2019/01/Woodcock-PSi01-Pete-Smith.jpg
# Woodcock
# https://birdwatchireland.ie/app/uploads/2019/01/Woodpigeon-05-Daragh-Owens.jpg
# Woodpigeon
# https://birdwatchireland.ie/app/uploads/2019/01/Wren-46-Michael-Finn.jpg
# Wren
# https://birdwatchireland.ie/app/uploads/2019/01/Yellow-browed-Warbler-03Knockadoon-Head-Cork-29th-September-2012-Graham-Clarke.jpg
# Yellow-browed Warbler
# https://birdwatchireland.ie/app/uploads/2019/04/Yellowhammer-54-Shay-Connolly-e1556096147600.jpg
# Yellowhammer

# %%
for i in range(0,2):
    img = Image.fromarray(df_birds['Image'][i])
    img.show()

# %% [markdown]
# ---
# <img title="GitHub Mark" src="./img/GitHub-Mark-64px.png?raw=true" style="height: 32px; padding-right: 15px" alt="GitHub Mark" align="left"> [GitHub repository](https://github.com/pessini/avian-flu-wild-birds-ireland) <br>Author: Leandro Pessini
